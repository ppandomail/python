# %% [markdown]
# # Pandas - Visualization (matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/ppando/Materias/python/doc/data/pandas_datos.csv')

# %% [markdown]
# ## Línea por defecto

# %%
df.plot()
plt.show()

# %% [markdown]
# ## Dispersión

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()

# %% [markdown]
# * Se visualiza muy buena correlación entre ambas variables (Duration vs Calories)

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')
plt.show()

# %% [markdown]
# * Se visualiza muy mala correlación entre ambas variables (Duration vs Maxpulse)

# %% [markdown]
# ## Histograma

# %%
df['Duration'].plot(kind = 'hist')     
plt.show()

# %% [markdown]
# * Se visualiza que hubo más de 100 entrenamientos que duraron entre 50 y 60 minutos
